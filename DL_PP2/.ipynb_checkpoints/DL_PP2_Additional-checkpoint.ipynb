# %% [markdown]
# # Deep Learning
# ## Practice Projects
# # P2 Additional: Noise Reduction for Multi-Label Classification
# ## Style and Libraries

# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron|Roboto');
# body {background-color: aliceblue;}
# a {color: #4876ff; font-family: 'Roboto';}
# h1 {color: #348ABD; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h2, h3 {color: slategray; font-family: 'Roboto'; text-shadow: 4px 4px 4px #ccc;}
# h4 {color: #348ABD; font-family: 'Orbitron';}
# span {text-shadow: 4px 4px 4px #ccc;}
# div.output_prompt, div.output_area pre {color: slategray;}
# div.input_prompt, div.output_subarea {color: #4876ff;}
# div.output_stderr pre {background-color: aliceblue;}
# div.output_stderr {background-color: slategrey;}
# </style>
# <script>
# code_show = true;
# function code_display() {
#     if (code_show) {
#         $('div.input').each(function(id) {
#             if (id == 0 || $(this).html().indexOf('hide_code') > -1) {$(this).hide();}
#         });
#         $('div.output_prompt').css('opacity', 0);
#     } else {
#         $('div.input').each(function(id) {$(this).show();});
#         $('div.output_prompt').css('opacity', 1);
#     };
#     code_show = !code_show;
# }
# $(document).ready(code_display);
# </script>
# <form action="javascript: code_display()">
# <input style="color: #348ABD; background: aliceblue; opacity: 0.8;" \
# type="submit" value="Click to display or hide code cells">
# </form>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron|Roboto');
# body {background-color: aliceblue;}
# a {color: #4876ff; font-family: 'Roboto';}
# h1 {color: #348ABD; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h2, h3 {color: slategray; font-family: 'Roboto'; text-shadow: 4px 4px 4px #ccc;}
# h4 {color: #348ABD; font-family: 'Orbitron';}
# span {text-shadow: 4px 4px 4px #ccc;}
# div.output_prompt, div.output_area pre {color: slategray;}
# div.input_prompt, div.output_subarea {color: #4876ff;}
# div.output_stderr pre {background-color: aliceblue;}
# div.output_stderr {background-color: slategrey;}
# </style>
# <script>
# code_show = true;
# function code_display() {
#     if (code_show) {
#         $('div.input').each(function(id) {
#             if (id == 0 || $(this).html().indexOf('hide_code') > -1) {$(this).hide();}
#         });
#         $('div.output_prompt').css('opacity', 0);
#     } else {
#         $('div.input').each(function(id) {$(this).show();});
#         $('div.output_prompt').css('opacity', 1);
#     };
#     code_show = !code_show;
# }
# $(document).ready(code_display);
# </script>
# <form action="javascript: code_display()">
# <input style="color: #348ABD; background: aliceblue; opacity: 0.8;" \
# type="submit" value="Click to display or hide code cells">
# </form>

# %%
hide_code = ''
import numpy as np 
import pandas as pd
import math

import tensorflow as tf

from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

import h5py
import cv2

from keras.models import Sequential, load_model, Model
from keras.layers import Input, UpSampling2D
from keras.layers import Dense, LSTM, GlobalAveragePooling1D, GlobalAveragePooling2D
from keras.layers import Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D

import matplotlib.pylab as plt
from matplotlib import cm
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Step 1. Load and Explore the Data

# %%
hide_code
# Read the h5 file
f = h5py.File('LetterColorImages_23.h5', 'r')

# List all groups
keys = list(f.keys())
keys
# Out:
# ['backgrounds', 'images', 'labels']

# %%
hide_code
# Create tensors and targets
backgrounds = np.array(f[keys[0]])
tensors = np.array(f[keys[1]])
targets = np.array(f[keys[2]])
print ('Tensor shape:', tensors.shape)
print ('Target shape', targets.shape)
print ('Background shape:', backgrounds.shape)
# Out:
# Tensor shape: (12540, 32, 32, 3)
# Target shape (12540,)
# Background shape: (12540,)

# %%
hide_code
# Plot letter images
fig, ax = plt.subplots(figsize=(18, 3), nrows=1, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(5):
    image = tensors[i*2000]/255
    ax[i].imshow(image)

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.gcf()
ax[2].set_title('Examples of letters', fontsize=25);

# %% [markdown]
# ## Step 2. Preprocess

# %%
hide_code
# Normalize the tensors
tensors = tensors.astype('float32')/255

# %%
hide_code
# Grayscaled tensors
gray_tensors = np.dot(tensors[...,:3], [0.299, 0.587, 0.114])
gray_tensors = gray_tensors.reshape(-1, 32, 32, 1)
print ('Grayscaled Tensor shape:', gray_tensors.shape)
# Out:
# Grayscaled Tensor shape: (12540, 32, 32, 1)

# %%
hide_code
# One-hot encode the targets, started from the zero label
cat_targets = to_categorical(np.array(targets-1), 33)
cat_targets.shape
# Out:
# (12540, 33)

# %%
hide_code
# One-hot encode the background targets
backgrounds = to_categorical(backgrounds-2,2)
backgrounds.shape
# Out:
# (12540, 2)

# %%
hide_code
# Create multi-label targets
back_targets = np.concatenate((cat_targets, backgrounds), axis=1)
back_targets.shape
# Out:
# (12540, 35)

# %%
hide_code
# Split the grayscaled data
x_train, x_test, y_train, y_test = train_test_split(gray_tensors, cat_targets, 
                                                    test_size = 0.2, 
                                                    random_state = 1)

n = int(len(x_test)/2)
x_valid, y_valid = x_test[:n], y_test[:n]
x_test, y_test = x_test[n:], y_test[n:]

# %%
hide_code
# Split the grayscaled data
x_train2, x_test2, y_train2, y_test2 = train_test_split(gray_tensors, back_targets, 
                                                        test_size = 0.2, 
                                                        random_state = 1)
n = int(len(x_test2)/2)
x_valid2, y_valid2 = x_test2[:n], y_test2[:n]
x_test2, y_test2 = x_test2[n:], y_test2[n:]

# %% [markdown]
# ## Step 3. Create Neural Networks for Noise Reduction
# #### TensorFlow; Less Compressed Images

# %%
hide_code
# NN for noise reduction

inputs_ = tf.placeholder(tf.float32, (None, 32, 32, 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, 32, 32, 1), name='targets')

### Encoder
conv1 = tf.layers.conv2d(inputs_, 32, (3,3), padding='same', activation=tf.nn.relu)
# Now 32x32x32
maxpool1 = tf.layers.max_pooling2d(conv1, (2,2), (2,2), padding='same')
# Now 16x16x32
conv2 = tf.layers.conv2d(maxpool1, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 16x16x16
maxpool2 = tf.layers.max_pooling2d(conv2, (2,2), (2,2), padding='same')
# Now 8x8x16
conv3 = tf.layers.conv2d(maxpool2, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 8x8x16
encoded = tf.layers.max_pooling2d(conv3, (2,2), (2,2), padding='same')
# Now 4x4x16

### Decoder
upsample1 = tf.image.resize_nearest_neighbor(encoded, (8,8))
# Now 8x8x16
conv4 = tf.layers.conv2d(upsample1, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 8x8x16
upsample2 = tf.image.resize_nearest_neighbor(conv4, (16,16))
# Now 16x16x16
conv5 = tf.layers.conv2d(upsample2, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 16x16x16
upsample3 = tf.image.resize_nearest_neighbor(conv5, (32,32))
# Now 32x32x16
conv6 = tf.layers.conv2d(upsample3, 32, (3,3), padding='same', activation=tf.nn.relu)
# Now 32x32x32

logits = tf.layers.conv2d(conv6, 1, (3,3), padding='same', activation=None)
# Now 32x32x1

decoded = tf.nn.sigmoid(logits, name='decoded')

loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(0.001).minimize(cost)

# %%
hide_code
# Function for creating batches
def get_batches(images, batch_size):
    current_index = 0
    while current_index + batch_size <= images.shape[0]:
        data_batch = images[current_index:current_index + batch_size]
        current_index += batch_size
        yield data_batch

# %%
hide_code
# Define parameters
epochs = 100
batch_size = 64
train_step = 0

# %%
hide_code
# Run the tensorflow session 
sess = tf.Session()
sess.run(tf.global_variables_initializer())
gray_tensors1 = np.copy(gray_tensors)

for e in range(epochs):
    for batch_images in get_batches(gray_tensors1, batch_size):
        train_step += 1
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: batch_images,
                                                         targets_: batch_images})
        if train_step % 200 == 0:
            print("Epoch: {}/{}...".format(e+1, epochs),
                  "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 2/100... Training loss: 0.6921
# Epoch: 3/100... Training loss: 0.6891
# Epoch: 4/100... Training loss: 0.6884
# Epoch: 5/100... Training loss: 0.6837
# Epoch: 6/100... Training loss: 0.6348
# Epoch: 7/100... Training loss: 0.6206
# Epoch: 8/100... Training loss: 0.6283
# Epoch: 9/100... Training loss: 0.6413
# Epoch: 10/100... Training loss: 0.6218
# Epoch: 11/100... Training loss: 0.6777
# Epoch: 12/100... Training loss: 0.6820
# Epoch: 13/100... Training loss: 0.6010
# Epoch: 14/100... Training loss: 0.6746
# Epoch: 15/100... Training loss: 0.6462
# Epoch: 16/100... Training loss: 0.6235
# Epoch: 17/100... Training loss: 0.6338
# Epoch: 18/100... Training loss: 0.6770
# Epoch: 19/100... Training loss: 0.6797
# Epoch: 20/100... Training loss: 0.6144
# Epoch: 21/100... Training loss: 0.6281
# Epoch: 22/100... Training loss: 0.6782
# Epoch: 23/100... Training loss: 0.6296
# Epoch: 24/100... Training loss: 0.6360
# Epoch: 25/100... Training loss: 0.6062
# Epoch: 26/100... Training loss: 0.6753
# Epoch: 27/100... Training loss: 0.6358
# Epoch: 28/100... Training loss: 0.6229
# Epoch: 29/100... Training loss: 0.6224
# Epoch: 30/100... Training loss: 0.6258
# Epoch: 31/100... Training loss: 0.6602
# Epoch: 32/100... Training loss: 0.6054
# Epoch: 33/100... Training loss: 0.5983
# Epoch: 34/100... Training loss: 0.6435
# Epoch: 35/100... Training loss: 0.6726
# Epoch: 36/100... Training loss: 0.6035
# Epoch: 37/100... Training loss: 0.6133
# Epoch: 38/100... Training loss: 0.6776
# Epoch: 39/100... Training loss: 0.6719
# Epoch: 40/100... Training loss: 0.6778
# Epoch: 42/100... Training loss: 0.6803
# Epoch: 43/100... Training loss: 0.6764
# Epoch: 44/100... Training loss: 0.6783
# Epoch: 45/100... Training loss: 0.6730
# Epoch: 46/100... Training loss: 0.6328
# Epoch: 47/100... Training loss: 0.6184
# Epoch: 48/100... Training loss: 0.6264
# Epoch: 49/100... Training loss: 0.6396
# Epoch: 50/100... Training loss: 0.6196
# Epoch: 51/100... Training loss: 0.6762
# Epoch: 52/100... Training loss: 0.6812
# Epoch: 53/100... Training loss: 0.5999
# Epoch: 54/100... Training loss: 0.6739
# Epoch: 55/100... Training loss: 0.6451
# Epoch: 56/100... Training loss: 0.6229
# Epoch: 57/100... Training loss: 0.6330
# Epoch: 58/100... Training loss: 0.6760
# Epoch: 59/100... Training loss: 0.6791
# Epoch: 60/100... Training loss: 0.6131
# Epoch: 61/100... Training loss: 0.6271
# Epoch: 62/100... Training loss: 0.6775
# Epoch: 63/100... Training loss: 0.6287
# Epoch: 64/100... Training loss: 0.6353
# Epoch: 65/100... Training loss: 0.6056
# Epoch: 66/100... Training loss: 0.6746
# Epoch: 67/100... Training loss: 0.6353
# Epoch: 68/100... Training loss: 0.6222
# Epoch: 69/100... Training loss: 0.6219
# Epoch: 70/100... Training loss: 0.6253
# Epoch: 71/100... Training loss: 0.6597
# Epoch: 72/100... Training loss: 0.6050
# Epoch: 73/100... Training loss: 0.5959
# Epoch: 74/100... Training loss: 0.6424
# Epoch: 75/100... Training loss: 0.6712
# Epoch: 76/100... Training loss: 0.6020
# Epoch: 77/100... Training loss: 0.6111
# Epoch: 78/100... Training loss: 0.6762
# Epoch: 79/100... Training loss: 0.6707
# Epoch: 80/100... Training loss: 0.6764
# Epoch: 82/100... Training loss: 0.6802
# Epoch: 83/100... Training loss: 0.6762
# Epoch: 84/100... Training loss: 0.6782
# Epoch: 85/100... Training loss: 0.6728
# Epoch: 86/100... Training loss: 0.6327
# Epoch: 87/100... Training loss: 0.6182
# Epoch: 88/100... Training loss: 0.6261
# Epoch: 89/100... Training loss: 0.6395
# Epoch: 90/100... Training loss: 0.6194
# Epoch: 91/100... Training loss: 0.6761
# Epoch: 92/100... Training loss: 0.6811
# Epoch: 93/100... Training loss: 0.5996
# Epoch: 94/100... Training loss: 0.6738
# Epoch: 95/100... Training loss: 0.6449
# Epoch: 96/100... Training loss: 0.6228
# Epoch: 97/100... Training loss: 0.6328
# Epoch: 98/100... Training loss: 0.6757
# Epoch: 99/100... Training loss: 0.6793
# Epoch: 100/100... Training loss: 0.6126

# %%
hide_code
# Display original grayscaled images
fig, ax = plt.subplots(figsize=(18, 3), nrows=1, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(5):
    image = gray_tensors[i*2000].reshape(32,32)
    ax[i].imshow(image, cmap=cm.bone)

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.gcf()
ax[2].set_title('Examples of grayscaled images', fontsize=25);

# %%
hide_code
# Display output grayscaled images
fig, ax = plt.subplots(figsize=(18, 3), nrows=1, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(5):
    image = gray_tensors1[i*2000].reshape(32,32)
    ax[i].imshow(image, cmap=cm.bone)

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.gcf()
ax[2].set_title('Examples of cleaned images. TensorFlow', fontsize=25);

# %% [markdown]
# #### Keras; More Compressed Images

# %%
hide_code
def autoencoder():
    inputs = Input(shape=(32, 32, 1))
    
    # Encode
    x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
    x = MaxPooling2D(padding='same')(x)
    
    x = Conv2D(16, 3, activation='relu', padding='same')(x)
    x = MaxPooling2D(padding='same')(x)
    
    x = Conv2D(8, 3, activation='relu', padding='same')(x)
    encoded = MaxPooling2D(padding='same')(x)    
    
    # Decode
    x = Conv2D(8, 3, activation='relu', padding='same')(encoded)
    x = UpSampling2D()(x)
    
    x = Conv2D(16, 3, activation='relu', padding='same')(x)
    x = UpSampling2D()(x)
    
    x = Conv2D(32, 3, activation='relu', padding='same')(x) 
    x = UpSampling2D()(x)
    
    decoded = Conv2D(1, 3, activation='sigmoid', padding='same')(x)
    
    # Autoencoder
    autoencoder = Model(inputs, decoded)
    
    # Compile
    autoencoder.compile(optimizer='nadam', loss='binary_crossentropy')
    
    return autoencoder

autoencoder = autoencoder()

# %%
hide_code
# Display autoencoder architecture 
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 8)           1160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 16)          1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 1)         289
# =================================================================
# Total params: 12,785
# Trainable params: 12,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
hide_code
# Train autoencoder
autoencoder_history = autoencoder.fit(x_train, x_train, 
                                      epochs=300, batch_size=64, verbose=2,
                                      validation_data=(x_valid, x_valid))
# Out:
# Train on 10032 samples, validate on 1254 samples
# Epoch 1/300
# 71s - loss: 0.6588 - val_loss: 0.6491
# Epoch 2/300
# 45s - loss: 0.6475 - val_loss: 0.6464
# Epoch 3/300
# 45s - loss: 0.6458 - val_loss: 0.6493
# Epoch 4/300
# 46s - loss: 0.6452 - val_loss: 0.6466
# Epoch 5/300
# 47s - loss: 0.6446 - val_loss: 0.6455
# Epoch 6/300
# 44s - loss: 0.6444 - val_loss: 0.6447
# Epoch 7/300
# 54s - loss: 0.6442 - val_loss: 0.6446
# Epoch 8/300
# 56s - loss: 0.6440 - val_loss: 0.6454
# Epoch 9/300
# 43s - loss: 0.6440 - val_loss: 0.6445
# Epoch 10/300
# 44s - loss: 0.6439 - val_loss: 0.6446
# Epoch 11/300
# 43s - loss: 0.6437 - val_loss: 0.6447
# Epoch 12/300
# 44s - loss: 0.6437 - val_loss: 0.6449
# Epoch 13/300
# 43s - loss: 0.6437 - val_loss: 0.6445
# Epoch 14/300
# 43s - loss: 0.6434 - val_loss: 0.6445
# Epoch 15/300
# 43s - loss: 0.6435 - val_loss: 0.6446
# Epoch 16/300
# 44s - loss: 0.6434 - val_loss: 0.6442
# Epoch 17/300
# 43s - loss: 0.6434 - val_loss: 0.6441
# Epoch 18/300
# 43s - loss: 0.6434 - val_loss: 0.6444
# Epoch 19/300
# 43s - loss: 0.6432 - val_loss: 0.6441
# Epoch 20/300
# 43s - loss: 0.6431 - val_loss: 0.6442
# Epoch 21/300
# 43s - loss: 0.6431 - val_loss: 0.6444
# Epoch 22/300
# 43s - loss: 0.6431 - val_loss: 0.6444
# Epoch 23/300
# 44s - loss: 0.6430 - val_loss: 0.6442
# Epoch 24/300
# 44s - loss: 0.6429 - val_loss: 0.6439
# Epoch 25/300
# 43s - loss: 0.6429 - val_loss: 0.6439
# Epoch 26/300
# 43s - loss: 0.6429 - val_loss: 0.6439
# Epoch 27/300
# 43s - loss: 0.6429 - val_loss: 0.6438
# Epoch 28/300
# 43s - loss: 0.6427 - val_loss: 0.6444
# Epoch 29/300
# 43s - loss: 0.6427 - val_loss: 0.6448
# Epoch 30/300
# 43s - loss: 0.6427 - val_loss: 0.6436
# Epoch 31/300
# 43s - loss: 0.6426 - val_loss: 0.6437
# Epoch 32/300
# 43s - loss: 0.6426 - val_loss: 0.6436
# Epoch 33/300
# 43s - loss: 0.6426 - val_loss: 0.6437
# Epoch 34/300
# 43s - loss: 0.6425 - val_loss: 0.6435
# Epoch 35/300
# 43s - loss: 0.6425 - val_loss: 0.6437
# Epoch 36/300
# 43s - loss: 0.6425 - val_loss: 0.6438
# Epoch 37/300
# 43s - loss: 0.6425 - val_loss: 0.6437
# Epoch 38/300
# 43s - loss: 0.6424 - val_loss: 0.6436
# Epoch 39/300
# 43s - loss: 0.6424 - val_loss: 0.6435
# Epoch 40/300
# 43s - loss: 0.6423 - val_loss: 0.6441
# Epoch 41/300
# 43s - loss: 0.6423 - val_loss: 0.6439
# Epoch 42/300
# 43s - loss: 0.6424 - val_loss: 0.6435
# Epoch 43/300
# 43s - loss: 0.6423 - val_loss: 0.6436
# Epoch 44/300
# 43s - loss: 0.6423 - val_loss: 0.6436
# Epoch 45/300
# 43s - loss: 0.6423 - val_loss: 0.6433
# Epoch 46/300
# 43s - loss: 0.6422 - val_loss: 0.6434
# Epoch 47/300
# 43s - loss: 0.6423 - val_loss: 0.6434
# Epoch 48/300
# 43s - loss: 0.6422 - val_loss: 0.6433
# Epoch 49/300
# 43s - loss: 0.6422 - val_loss: 0.6433
# Epoch 50/300
# 43s - loss: 0.6421 - val_loss: 0.6433
# Epoch 51/300
# 43s - loss: 0.6422 - val_loss: 0.6433
# Epoch 52/300
# 43s - loss: 0.6421 - val_loss: 0.6436
# Epoch 53/300
# 43s - loss: 0.6421 - val_loss: 0.6433
# Epoch 54/300
# 43s - loss: 0.6421 - val_loss: 0.6433
# Epoch 55/300
# 43s - loss: 0.6421 - val_loss: 0.6433
# Epoch 56/300
# 43s - loss: 0.6421 - val_loss: 0.6435
# Epoch 57/300
# 43s - loss: 0.6421 - val_loss: 0.6432
# Epoch 58/300
# 45s - loss: 0.6420 - val_loss: 0.6433
# Epoch 59/300
# 43s - loss: 0.6420 - val_loss: 0.6432
# Epoch 60/300
# 43s - loss: 0.6420 - val_loss: 0.6432
# Epoch 61/300
# 43s - loss: 0.6420 - val_loss: 0.6440
# Epoch 62/300
# 43s - loss: 0.6420 - val_loss: 0.6433
# Epoch 63/300
# 43s - loss: 0.6420 - val_loss: 0.6431
# Epoch 64/300
# 43s - loss: 0.6419 - val_loss: 0.6432
# Epoch 65/300
# 44s - loss: 0.6419 - val_loss: 0.6431
# Epoch 66/300
# 44s - loss: 0.6419 - val_loss: 0.6435
# Epoch 67/300
# 44s - loss: 0.6420 - val_loss: 0.6431
# Epoch 68/300
# 45s - loss: 0.6419 - val_loss: 0.6431
# Epoch 69/300
# 44s - loss: 0.6419 - val_loss: 0.6432
# Epoch 70/300
# 44s - loss: 0.6419 - val_loss: 0.6431
# Epoch 71/300
# 44s - loss: 0.6419 - val_loss: 0.6432
# Epoch 72/300
# 45s - loss: 0.6419 - val_loss: 0.6433
# Epoch 73/300
# 44s - loss: 0.6419 - val_loss: 0.6431
# Epoch 74/300
# 44s - loss: 0.6418 - val_loss: 0.6430
# Epoch 75/300
# 45s - loss: 0.6418 - val_loss: 0.6431
# Epoch 76/300
# 43s - loss: 0.6418 - val_loss: 0.6430
# Epoch 77/300
# 44s - loss: 0.6418 - val_loss: 0.6431
# Epoch 78/300
# 44s - loss: 0.6418 - val_loss: 0.6431
# Epoch 79/300
# 43s - loss: 0.6418 - val_loss: 0.6430
# Epoch 80/300
# 43s - loss: 0.6418 - val_loss: 0.6437
# Epoch 81/300
# 43s - loss: 0.6418 - val_loss: 0.6430
# Epoch 82/300
# 43s - loss: 0.6417 - val_loss: 0.6432
# Epoch 83/300
# 43s - loss: 0.6417 - val_loss: 0.6429
# Epoch 84/300
# 43s - loss: 0.6417 - val_loss: 0.6430
# Epoch 85/300
# 43s - loss: 0.6417 - val_loss: 0.6433
# Epoch 86/300
# 43s - loss: 0.6417 - val_loss: 0.6429
# Epoch 87/300
# 43s - loss: 0.6417 - val_loss: 0.6429
# Epoch 88/300
# 43s - loss: 0.6417 - val_loss: 0.6429
# Epoch 89/300
# 43s - loss: 0.6417 - val_loss: 0.6429
# Epoch 90/300
# 43s - loss: 0.6417 - val_loss: 0.6430
# Epoch 91/300
# 43s - loss: 0.6417 - val_loss: 0.6430
# Epoch 92/300
# 43s - loss: 0.6417 - val_loss: 0.6435
# Epoch 93/300
# 43s - loss: 0.6417 - val_loss: 0.6429
# Epoch 94/300
# 43s - loss: 0.6416 - val_loss: 0.6429
# Epoch 95/300
# 43s - loss: 0.6416 - val_loss: 0.6429
# Epoch 96/300
# 43s - loss: 0.6416 - val_loss: 0.6430
# Epoch 97/300
# 43s - loss: 0.6416 - val_loss: 0.6428
# Epoch 98/300
# 43s - loss: 0.6416 - val_loss: 0.6429
# Epoch 99/300
# 43s - loss: 0.6416 - val_loss: 0.6428
# Epoch 100/300
# 43s - loss: 0.6416 - val_loss: 0.6429
# Epoch 101/300
# 43s - loss: 0.6416 - val_loss: 0.6430
# Epoch 102/300
# 43s - loss: 0.6416 - val_loss: 0.6432
# Epoch 103/300
# 43s - loss: 0.6416 - val_loss: 0.6428
# Epoch 104/300
# 43s - loss: 0.6416 - val_loss: 0.6428
# Epoch 105/300
# 43s - loss: 0.6416 - val_loss: 0.6433
# Epoch 106/300
# 43s - loss: 0.6415 - val_loss: 0.6429
# Epoch 107/300
# 43s - loss: 0.6415 - val_loss: 0.6430
# Epoch 108/300
# 43s - loss: 0.6415 - val_loss: 0.6428
# Epoch 109/300
# 43s - loss: 0.6415 - val_loss: 0.6428
# Epoch 110/300
# 43s - loss: 0.6415 - val_loss: 0.6427
# Epoch 111/300
# 43s - loss: 0.6415 - val_loss: 0.6427
# Epoch 112/300
# 43s - loss: 0.6415 - val_loss: 0.6427
# Epoch 113/300
# 43s - loss: 0.6415 - val_loss: 0.6432
# Epoch 114/300
# 45s - loss: 0.6415 - val_loss: 0.6429
# Epoch 115/300
# 44s - loss: 0.6415 - val_loss: 0.6427
# Epoch 116/300
# 43s - loss: 0.6414 - val_loss: 0.6427
# Epoch 117/300
# 43s - loss: 0.6415 - val_loss: 0.6428
# Epoch 118/300
# 43s - loss: 0.6415 - val_loss: 0.6427
# Epoch 119/300
# 43s - loss: 0.6414 - val_loss: 0.6429
# Epoch 120/300
# 43s - loss: 0.6415 - val_loss: 0.6427
# Epoch 121/300
# 44s - loss: 0.6414 - val_loss: 0.6427
# Epoch 122/300
# 44s - loss: 0.6414 - val_loss: 0.6428
# Epoch 123/300
# 44s - loss: 0.6414 - val_loss: 0.6428
# Epoch 124/300
# 43s - loss: 0.6414 - val_loss: 0.6427
# Epoch 125/300
# 44s - loss: 0.6414 - val_loss: 0.6430
# Epoch 126/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 127/300
# 43s - loss: 0.6414 - val_loss: 0.6427
# Epoch 128/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 129/300
# 43s - loss: 0.6414 - val_loss: 0.6428
# Epoch 130/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 131/300
# 43s - loss: 0.6414 - val_loss: 0.6431
# Epoch 132/300
# 43s - loss: 0.6414 - val_loss: 0.6427
# Epoch 133/300
# 43s - loss: 0.6414 - val_loss: 0.6430
# Epoch 134/300
# 43s - loss: 0.6414 - val_loss: 0.6428
# Epoch 135/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 136/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 137/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 138/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 139/300
# 43s - loss: 0.6414 - val_loss: 0.6426
# Epoch 140/300
# 43s - loss: 0.6413 - val_loss: 0.6428
# Epoch 141/300
# 43s - loss: 0.6414 - val_loss: 0.6428
# Epoch 142/300
# 43s - loss: 0.6413 - val_loss: 0.6432
# Epoch 143/300
# 43s - loss: 0.6413 - val_loss: 0.6429
# Epoch 144/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 145/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 146/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 147/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 148/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 149/300
# 44s - loss: 0.6413 - val_loss: 0.6426
# Epoch 150/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 151/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 152/300
# 43s - loss: 0.6413 - val_loss: 0.6429
# Epoch 153/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 154/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 155/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 156/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 157/300
# 43s - loss: 0.6413 - val_loss: 0.6432
# Epoch 158/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 159/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 160/300
# 43s - loss: 0.6413 - val_loss: 0.6427
# Epoch 161/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 162/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 163/300
# 43s - loss: 0.6413 - val_loss: 0.6427
# Epoch 164/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 165/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 166/300
# 43s - loss: 0.6413 - val_loss: 0.6427
# Epoch 167/300
# 43s - loss: 0.6413 - val_loss: 0.6429
# Epoch 168/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 169/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 170/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 171/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 172/300
# 43s - loss: 0.6413 - val_loss: 0.6426
# Epoch 173/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 174/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 175/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 176/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 177/300
# 43s - loss: 0.6412 - val_loss: 0.6426
# Epoch 178/300
# 43s - loss: 0.6412 - val_loss: 0.6427
# Epoch 179/300
# 43s - loss: 0.6413 - val_loss: 0.6425
# Epoch 180/300
# 43s - loss: 0.6412 - val_loss: 0.6426
# Epoch 181/300
# 43s - loss: 0.6412 - val_loss: 0.6427
# Epoch 182/300
# 43s - loss: 0.6412 - val_loss: 0.6430
# Epoch 183/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 184/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 185/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 186/300
# 43s - loss: 0.6412 - val_loss: 0.6426
# Epoch 187/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 188/300
# 44s - loss: 0.6412 - val_loss: 0.6425
# Epoch 189/300
# 43s - loss: 0.6412 - val_loss: 0.6426
# Epoch 190/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 191/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 192/300
# 43s - loss: 0.6412 - val_loss: 0.6425
# Epoch 193/300
# 47s - loss: 0.6412 - val_loss: 0.6425
# Epoch 194/300
# 49s - loss: 0.6412 - val_loss: 0.6425
# Epoch 195/300
# 47s - loss: 0.6412 - val_loss: 0.6428
# Epoch 196/300
# 49s - loss: 0.6412 - val_loss: 0.6426
# Epoch 197/300
# 44s - loss: 0.6412 - val_loss: 0.6425
# Epoch 198/300
# 44s - loss: 0.6412 - val_loss: 0.6425
# Epoch 199/300
# 45s - loss: 0.6412 - val_loss: 0.6427
# Epoch 200/300
# 46s - loss: 0.6412 - val_loss: 0.6424
# Epoch 201/300
# 46s - loss: 0.6412 - val_loss: 0.6427
# Epoch 202/300
# 44s - loss: 0.6412 - val_loss: 0.6425
# Epoch 203/300
# 46s - loss: 0.6412 - val_loss: 0.6424
# Epoch 204/300
# 54s - loss: 0.6412 - val_loss: 0.6424
# Epoch 205/300
# 58s - loss: 0.6411 - val_loss: 0.6426
# Epoch 206/300
# 57s - loss: 0.6412 - val_loss: 0.6425
# Epoch 207/300
# 52s - loss: 0.6412 - val_loss: 0.6424
# Epoch 208/300
# 54s - loss: 0.6412 - val_loss: 0.6427
# Epoch 209/300
# 54s - loss: 0.6412 - val_loss: 0.6424
# Epoch 210/300
# 53s - loss: 0.6412 - val_loss: 0.6424
# Epoch 211/300
# 46s - loss: 0.6412 - val_loss: 0.6425
# Epoch 212/300
# 50s - loss: 0.6412 - val_loss: 0.6426
# Epoch 213/300
# 48s - loss: 0.6412 - val_loss: 0.6424
# Epoch 214/300
# 52s - loss: 0.6412 - val_loss: 0.6426
# Epoch 215/300
# 52s - loss: 0.6412 - val_loss: 0.6424
# Epoch 216/300
# 52s - loss: 0.6412 - val_loss: 0.6424
# Epoch 217/300
# 50s - loss: 0.6411 - val_loss: 0.6425
# Epoch 218/300
# 50s - loss: 0.6412 - val_loss: 0.6424
# Epoch 219/300
# 49s - loss: 0.6411 - val_loss: 0.6424
# Epoch 220/300
# 53s - loss: 0.6412 - val_loss: 0.6424
# Epoch 221/300
# 47s - loss: 0.6411 - val_loss: 0.6424
# Epoch 222/300
# 46s - loss: 0.6412 - val_loss: 0.6424
# Epoch 223/300
# 47s - loss: 0.6412 - val_loss: 0.6424
# Epoch 224/300
# 47s - loss: 0.6411 - val_loss: 0.6424
# Epoch 225/300
# 47s - loss: 0.6412 - val_loss: 0.6424
# Epoch 226/300
# 50s - loss: 0.6411 - val_loss: 0.6425
# Epoch 227/300
# 49s - loss: 0.6411 - val_loss: 0.6425
# Epoch 228/300
# 48s - loss: 0.6412 - val_loss: 0.6424
# Epoch 229/300
# 47s - loss: 0.6411 - val_loss: 0.6425
# Epoch 230/300
# 47s - loss: 0.6412 - val_loss: 0.6425
# Epoch 231/300
# 47s - loss: 0.6411 - val_loss: 0.6424
# Epoch 232/300
# 47s - loss: 0.6411 - val_loss: 0.6425
# Epoch 233/300
# 47s - loss: 0.6411 - val_loss: 0.6425
# Epoch 234/300
# 47s - loss: 0.6412 - val_loss: 0.6430
# Epoch 235/300
# 47s - loss: 0.6411 - val_loss: 0.6424
# Epoch 236/300
# 47s - loss: 0.6411 - val_loss: 0.6424
# Epoch 237/300
# 47s - loss: 0.6411 - val_loss: 0.6424
# Epoch 238/300
# 47s - loss: 0.6411 - val_loss: 0.6424
# Epoch 239/300
# 47s - loss: 0.6411 - val_loss: 0.6425
# Epoch 240/300
# 53s - loss: 0.6411 - val_loss: 0.6426
# Epoch 241/300
# 59s - loss: 0.6411 - val_loss: 0.6424
# Epoch 242/300
# 52s - loss: 0.6411 - val_loss: 0.6427
# Epoch 243/300
# 55s - loss: 0.6411 - val_loss: 0.6424
# Epoch 244/300
# 59s - loss: 0.6411 - val_loss: 0.6425
# Epoch 245/300
# 60s - loss: 0.6411 - val_loss: 0.6424
# Epoch 246/300
# 55s - loss: 0.6411 - val_loss: 0.6424
# Epoch 247/300
# 60s - loss: 0.6411 - val_loss: 0.6430
# Epoch 248/300
# 57s - loss: 0.6411 - val_loss: 0.6428
# Epoch 249/300
# 53s - loss: 0.6411 - val_loss: 0.6425
# Epoch 250/300
# 51s - loss: 0.6411 - val_loss: 0.6424
# Epoch 251/300
# 54s - loss: 0.6411 - val_loss: 0.6425
# Epoch 252/300
# 55s - loss: 0.6411 - val_loss: 0.6424
# Epoch 253/300
# 58s - loss: 0.6411 - val_loss: 0.6424
# Epoch 254/300
# 59s - loss: 0.6411 - val_loss: 0.6424
# Epoch 255/300
# 54s - loss: 0.6411 - val_loss: 0.6424
# Epoch 256/300
# 56s - loss: 0.6411 - val_loss: 0.6423
# Epoch 257/300
# 55s - loss: 0.6411 - val_loss: 0.6423
# Epoch 258/300
# 52s - loss: 0.6411 - val_loss: 0.6424
# Epoch 259/300
# 51s - loss: 0.6411 - val_loss: 0.6424
# Epoch 260/300
# 53s - loss: 0.6411 - val_loss: 0.6424
# Epoch 261/300
# 51s - loss: 0.6411 - val_loss: 0.6425
# Epoch 262/300
# 54s - loss: 0.6411 - val_loss: 0.6424
# Epoch 263/300
# 55s - loss: 0.6411 - val_loss: 0.6430
# Epoch 264/300
# 54s - loss: 0.6411 - val_loss: 0.6424
# Epoch 265/300
# 53s - loss: 0.6411 - val_loss: 0.6428
# Epoch 266/300
# 56s - loss: 0.6411 - val_loss: 0.6425
# Epoch 267/300
# 52s - loss: 0.6411 - val_loss: 0.6423
# Epoch 268/300
# 58s - loss: 0.6411 - val_loss: 0.6424
# Epoch 269/300
# 56s - loss: 0.6411 - val_loss: 0.6424
# Epoch 270/300
# 55s - loss: 0.6411 - val_loss: 0.6424
# Epoch 271/300
# 51s - loss: 0.6411 - val_loss: 0.6423
# Epoch 272/300
# 56s - loss: 0.6411 - val_loss: 0.6423
# Epoch 273/300
# 54s - loss: 0.6411 - val_loss: 0.6423
# Epoch 274/300
# 60s - loss: 0.6410 - val_loss: 0.6424
# Epoch 275/300
# 57s - loss: 0.6411 - val_loss: 0.6423
# Epoch 276/300
# 53s - loss: 0.6411 - val_loss: 0.6425
# Epoch 277/300
# 52s - loss: 0.6411 - val_loss: 0.6424
# Epoch 278/300
# 57s - loss: 0.6410 - val_loss: 0.6424
# Epoch 279/300
# 57s - loss: 0.6410 - val_loss: 0.6425
# Epoch 280/300
# 59s - loss: 0.6411 - val_loss: 0.6425
# Epoch 281/300
# 53s - loss: 0.6411 - val_loss: 0.6427
# Epoch 282/300
# 61s - loss: 0.6410 - val_loss: 0.6423
# Epoch 283/300
# 59s - loss: 0.6411 - val_loss: 0.6423
# Epoch 284/300
# 58s - loss: 0.6410 - val_loss: 0.6425
# Epoch 285/300
# 59s - loss: 0.6411 - val_loss: 0.6423
# Epoch 286/300
# 58s - loss: 0.6410 - val_loss: 0.6423
# Epoch 287/300
# 59s - loss: 0.6410 - val_loss: 0.6423
# Epoch 288/300
# 59s - loss: 0.6411 - val_loss: 0.6424
# Epoch 289/300
# 58s - loss: 0.6410 - val_loss: 0.6423
# Epoch 290/300
# 61s - loss: 0.6410 - val_loss: 0.6423
# Epoch 291/300
# 66s - loss: 0.6411 - val_loss: 0.6423
# Epoch 292/300
# 87s - loss: 0.6410 - val_loss: 0.6423
# Epoch 293/300
# 60s - loss: 0.6410 - val_loss: 0.6424
# Epoch 294/300
# 71s - loss: 0.6410 - val_loss: 0.6423
# Epoch 295/300
# 65s - loss: 0.6410 - val_loss: 0.6424
# Epoch 296/300
# 63s - loss: 0.6410 - val_loss: 0.6423
# Epoch 297/300
# 56s - loss: 0.6410 - val_loss: 0.6423
# Epoch 298/300
# 54s - loss: 0.6410 - val_loss: 0.6423
# Epoch 299/300
# 51s - loss: 0.6410 - val_loss: 0.6423
# Epoch 300/300
# 51s - loss: 0.6410 - val_loss: 0.6425

# %%
hide_code
# Plot training history
plt.figure(figsize=(18, 6))
plt.plot(autoencoder_history.history['loss'][2:], color='slategray', label = 'train')
plt.plot(autoencoder_history.history['val_loss'][2:], color='#4876ff', label = 'valid')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title('Loss Function');

# %%
hide_code
# Create decoded images
x_test_decoded = autoencoder.predict(x_test)

# %%
hide_code
fig, ax = plt.subplots(figsize=(18, 3), nrows=1, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(5):
    image = x_test[i*150].reshape(32,32)
    ax[i].imshow(image, cmap=cm.bone)

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.gcf()
ax[2].set_title('Examples of grayscaled letters', fontsize=25);

# %%
hide_code
fig, ax = plt.subplots(figsize=(18, 3), nrows=1, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(5):
    image = x_test_decoded[i*150].reshape(32,32)
    ax[i].imshow(image, cmap=cm.bone)

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.gcf()
ax[2].set_title('Examples of cleaned letters. Keras', fontsize=25);
