# %% [markdown]
# # Deep Learning
# ## Practice Projects
# # P5: Decor Colorization
#
# ## Step 0. Style and Libraries
# Let's choose a style of the Jupyter notebook and import the software libraries. The command hide_code will hide the code cells.

# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron|Roboto');
# body {background-color: aliceblue;}
# a {color: #4876ff; font-family: 'Roboto';}
# h1 {color: #348ABD; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h2, h3 {color: slategray; font-family: 'Roboto'; text-shadow: 4px 4px 4px #ccc;}
# h4 {color: #348ABD; font-family: 'Orbitron';}
# span {text-shadow: 4px 4px 4px #ccc;}
# div.output_prompt, div.output_area pre {color: slategray;}
# div.input_prompt, div.output_subarea {color: #4876ff;}
# div.output_stderr pre {background-color: aliceblue;}
# div.output_stderr {background-color: slategrey;}
# </style>
# <script>
# code_show = true;
# function code_display() {
#     if (code_show) {
#         $('div.input').each(function(id) {
#             if (id == 0 || $(this).html().indexOf('hide_code') > -1) {$(this).hide();}
#         });
#         $('div.output_prompt').css('opacity', 0);
#     } else {
#         $('div.input').each(function(id) {$(this).show();});
#         $('div.output_prompt').css('opacity', 1);
#     };
#     code_show = !code_show;
# }
# $(document).ready(code_display);
# </script>
# <form action="javascript: code_display()">
# <input style="color: #348ABD; background: aliceblue; opacity: 0.8;" \
# type="submit" value="Click to display or hide code cells">
# </form>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron|Roboto');
# body {background-color: aliceblue;}
# a {color: #4876ff; font-family: 'Roboto';}
# h1 {color: #348ABD; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h2, h3 {color: slategray; font-family: 'Roboto'; text-shadow: 4px 4px 4px #ccc;}
# h4 {color: #348ABD; font-family: 'Orbitron';}
# span {text-shadow: 4px 4px 4px #ccc;}
# div.output_prompt, div.output_area pre {color: slategray;}
# div.input_prompt, div.output_subarea {color: #4876ff;}
# div.output_stderr pre {background-color: aliceblue;}
# div.output_stderr {background-color: slategrey;}
# </style>
# <script>
# code_show = true;
# function code_display() {
#     if (code_show) {
#         $('div.input').each(function(id) {
#             if (id == 0 || $(this).html().indexOf('hide_code') > -1) {$(this).hide();}
#         });
#         $('div.output_prompt').css('opacity', 0);
#     } else {
#         $('div.input').each(function(id) {$(this).show();});
#         $('div.output_prompt').css('opacity', 1);
#     };
#     code_show = !code_show;
# }
# $(document).ready(code_display);
# </script>
# <form action="javascript: code_display()">
# <input style="color: #348ABD; background: aliceblue; opacity: 0.8;" \
# type="submit" value="Click to display or hide code cells">
# </form>

# %%
hide_code = ''
import numpy as np 
import pandas as pd
import tensorflow as tf

from PIL import ImageFile
from tqdm import tqdm
import h5py
import cv2

import matplotlib.pylab as plt
from matplotlib import cm
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

from keras.utils import to_categorical
from keras.preprocessing import image as keras_image
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential, load_model, Model
from keras.layers import Input, BatchNormalization, LeakyReLU
from keras.layers import Dense, LSTM, GlobalAveragePooling1D, GlobalAveragePooling2D
from keras.layers import Activation, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D

from keras.applications.inception_v3 import InceptionV3, preprocess_input
import scipy
from scipy import misc
from skimage import color, measure

# %%
hide_code
# Plot the neural network fitting history
def history_plot(fit_history, n):
    plt.figure(figsize=(18, 12))
    
    plt.subplot(211)
    plt.plot(fit_history.history['loss'][n:], color='slategray', label = 'train')
    plt.plot(fit_history.history['val_loss'][n:], color='#4876ff', label = 'valid')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.title('Loss Function');  
    
    plt.subplot(212)
    plt.plot(fit_history.history['acc'][n:], color='slategray', label = 'train')
    plt.plot(fit_history.history['val_acc'][n:], color='#4876ff', label = 'valid')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")    
    plt.legend()
    plt.title('Accuracy');

# %% [markdown]
# ## Step 1. Load and Explore the Data
# For this project, I have created the dataset of color images (150x150x3) with traditional patterns. Run the following cells to download the data.

# %%
hide_code
# Function for processing an image
def image_to_tensor(img_path, folder_path):
    img = keras_image.load_img(folder_path + img_path, target_size=(150, 150))
    x = keras_image.img_to_array(img)
    return np.expand_dims(x, axis=0)
# Function for creating the data tensor
def data_to_tensor(img_paths, folder_path):
    list_of_tensors = [image_to_tensor(img_path, folder_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
hide_code
# Load the dataset 
data = pd.read_csv("decor.txt")
files = data['file']

countries = data['country_label'].as_matrix()
decors = data['decor_label'].as_matrix()
types = data['type_label'].as_matrix()

images = data_to_tensor(files, "data/");
# Out:
# 100%|██████████| 485/485 [00:14<00:00, 33.86it/s]

# %%
hide_code
# Print the shape 
print ('Image shape:', images.shape)
print ('Country shape:', countries.shape)
print ('Decor shape:', decors.shape)
print ('Type shape:', types.shape)
# Out:
# Image shape: (485, 150, 150, 3)
# Country shape: (485,)
# Decor shape: (485,)
# Type shape: (485,)

# %%
hide_code
# Read from files and display images using OpenCV
def display_images(img_path, ax):
    img = cv2.imread("data/" + img_path)
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    
fig = plt.figure(figsize=(18, 6))
for i in range(10):
    ax = fig.add_subplot(2, 5, i + 1, xticks=[], yticks=[], 
                         title=data['country'][i*48]+'; '+data['decor'][i*48]+'; '+data['type'][i*48])
    display_images(files[i*48], ax)

# %% [markdown]
# ## Step 2. Save and Load the Data
# The data tensors can be saved in the appropriate format of files .h5.

# %%
hide_code
# Create the tensor file
with h5py.File('DecorColorImages.h5', 'w') as f:
    f.create_dataset('images', data = images)
    f.create_dataset('countries', data = countries)
    f.create_dataset('decors', data = decors)
    f.create_dataset('types', data = types)
    f.close()

# %%
hide_code
# Read the h5 file
f = h5py.File('DecorColorImages.h5', 'r')

# List all groups
keys = list(f.keys())
keys
# Out:
# ['countries', 'decors', 'images', 'types']

# %%
hide_code
# Create tensors and targets
countries = np.array(f[keys[0]])
decors = np.array(f[keys[1]])
images = np.array(f[keys[2]])
types = np.array(f[keys[3]])

print ('Image shape:', images.shape)
print ('Country shape:', countries.shape)
print ('Decor shape:', decors.shape)
print ('Type shape:', types.shape)
# Out:
# Image shape: (485, 150, 150, 3)
# Country shape: (485,)
# Decor shape: (485,)
# Type shape: (485,)

# %% [markdown]
# ## Step 3. Implement Preprocess Functions

# %%
hide_code
# Normalize the tensors
images = images.astype('float32')/255

# %%
hide_code
# Read and display a tensor using Matplotlib
pattern_number = 106
print('Country: ', countries[pattern_number], '-', data['country'][pattern_number])
print('Decor: ', decors[pattern_number], '-', data['decor'][pattern_number])
print('Type: ', types[pattern_number], '-', data['type'][pattern_number])
plt.figure(figsize=(5,5))
plt.imshow(images[pattern_number]);
# Out:
# Country:  1 - Russia
# Decor:  2 - Khokhloma
# Type:  1 - pattern

# %%
hide_code
# Vectorize an image example / Just for fun
example = images[pattern_number]
gray_example = color.colorconv.rgb2grey(example)
contours = measure.find_contours(gray_example, 0.85)
plt.figure(figsize=(5,5))
for n, contour in enumerate(contours):
    plt.plot(contour[:, 1], contour[:, 0], lw=1)

# %%
hide_code
# Grayscaled tensors
gray_images = np.dot(images[...,:3], [0.299, 0.587, 0.114])
print ("Shape of grayscaled images:", gray_images.shape)
# Out:
# Shape of grayscaled images: (485, 150, 150)

# %%
hide_code
# Read and display a grayscaled tensor using Matplotlib
print('Country: ', countries[pattern_number], '-', data['country'][pattern_number])
print('Decor: ', decors[pattern_number], '-', data['decor'][pattern_number])
print('Type: ', types[pattern_number], '-', data['type'][pattern_number])
plt.figure(figsize=(5,5))
plt.imshow(gray_images[pattern_number], cmap=cm.bone);
# Out:
# Country:  1 - Russia
# Decor:  2 - Khokhloma
# Type:  1 - pattern

# %%
hide_code
# Print the target unique values
print('Countries: ', set(countries))
print('Decors: ', set(decors))
print('Types: ', set(types))
# Out:
# Countries:  {1, 2, 3, 4}
# Decors:  {1, 2, 3, 4, 5, 6, 7}
# Types:  {1, 2}

# %%
# One-hot encode the targets, started from the zero label
cat_countries = to_categorical(np.array(countries-1), 4)
cat_decors = to_categorical(np.array(decors-1), 7)
cat_types = to_categorical(np.array(types-1), 2)
cat_countries.shape, cat_decors.shape, cat_types.shape
# Out:
# ((485, 4), (485, 7), (485, 2))

# %%
# Create multi-label targets
targets = np.concatenate((cat_countries, cat_decors), axis=1)
targets = np.concatenate((targets, cat_types), axis=1)
targets.shape
# Out:
# (485, 13)

# %%
hide_code
# Split the data / Color images / Country
x_train, x_test, y_train, y_test = train_test_split(images, cat_countries, 
                                                    test_size = 0.2, 
                                                    random_state = 1)
n = int(len(x_test)/2)
x_valid, y_valid = x_test[:n], y_test[:n]
x_test, y_test = x_test[n:], y_test[n:]

# %%
hide_code
# Split the data / Color images / Decor
x_train3, x_test3, y_train3, y_test3 = train_test_split(images, cat_decors, 
                                                        test_size = 0.2, 
                                                        random_state = 1)
n = int(len(x_test3)/2)
x_valid3, y_valid3 = x_test3[:n], y_test3[:n]
x_test3, y_test3 = x_test3[n:], y_test3[n:]

# %%
hide_code
# Split the data / Grayscaled images / Country
x_train2, x_test2, y_train2, y_test2 = train_test_split(gray_images, cat_countries, 
                                                        test_size = 0.2, 
                                                        random_state = 1)
n = int(len(x_test2)/2)
x_valid2, y_valid2 = x_test2[:n], y_test2[:n]
x_test2, y_test2 = x_test2[n:], y_test2[n:]

# %%
hide_code
# Reshape the grayscaled data
x_train2, x_test2, x_valid2 = \
x_train2.reshape(-1, 150, 150, 1), \
x_test2.reshape(-1, 150, 150, 1), \
x_valid2.reshape(-1, 150, 150, 1)

# %%
hide_code
# Split the data / Grayscaled images / Decor
x_train4, x_test4, y_train4, y_test4 = train_test_split(gray_images, cat_decors, 
                                                        test_size = 0.2, 
                                                        random_state = 1)
n = int(len(x_test4)/2)
x_valid4, y_valid4 = x_test4[:n], y_test4[:n]
x_test4, y_test4 = x_test4[n:], y_test4[n:]

# %%
hide_code
# Reshape the grayscaled data
x_train4, x_test4, x_valid4 = \
x_train4.reshape(-1, 150, 150, 1), \
x_test4.reshape(-1, 150, 150, 1), \
x_valid4.reshape(-1, 150, 150, 1)

# %% [markdown]
# ## Step 4. Create Neural Networks for One-Label Classification

# %%
hide_code
# Plot the neural network fitting history
def history_plot(fit_history, n):
    plt.figure(figsize=(18, 12))
    
    plt.subplot(211)
    plt.plot(fit_history.history['loss'][n:], color='slategray', label = 'train')
    plt.plot(fit_history.history['val_loss'][n:], color='#4876ff', label = 'valid')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.title('Loss Function');  
    
    plt.subplot(212)
    plt.plot(fit_history.history['acc'][n:], color='slategray', label = 'train')
    plt.plot(fit_history.history['val_acc'][n:], color='#4876ff', label = 'valid')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")    
    plt.legend()
    plt.title('Accuracy');

# %% [markdown]
# #### Country & Decor Recognition for Color Images

# %%
hide_code
def cc_model():
    model = Sequential()
    # TODO: Define a model architecture
    model.add(Conv2D(32, (5, 5), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(96, (5, 5)))
    model.add(Activation('relu'))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(GlobalMaxPooling2D()) 
    
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.25)) 
    
    model.add(Dense(4))
    model.add(Activation('softmax'))
    
    # TODO: Compile the model
    model.compile(loss='categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])
    
    return model

# %%
hide_code
# Train the model
cc_model = cc_model()
cc_checkpointer = ModelCheckpoint(filepath='weights.best.decor.cc_model.hdf5', 
                                  verbose=2, save_best_only=True)
cc_history = cc_model.fit(x_train, y_train, 
                          epochs=20, batch_size=16, verbose=2,
                          validation_data=(x_valid, y_valid),
                          callbacks=[cc_checkpointer])
# Out:
# Train on 388 samples, validate on 48 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 1.35105, saving model to weights.best.decor.cc_model.hdf5
# 58s - loss: 1.1867 - acc: 0.5644 - val_loss: 1.3511 - val_acc: 0.4583
# Epoch 2/20
# Epoch 00001: val_loss did not improve
# 65s - loss: 1.0978 - acc: 0.5851 - val_loss: 1.6851 - val_acc: 0.0417
# Epoch 3/20
# Epoch 00002: val_loss improved from 1.35105 to 1.19737, saving model to weights.best.decor.cc_model.hdf5
# 57s - loss: 1.0817 - acc: 0.5464 - val_loss: 1.1974 - val_acc: 0.5417
# Epoch 4/20
# Epoch 00003: val_loss did not improve
# 54s - loss: 1.0356 - acc: 0.5928 - val_loss: 1.6451 - val_acc: 0.5417
# Epoch 5/20
# Epoch 00004: val_loss improved from 1.19737 to 1.07348, saving model to weights.best.decor.cc_model.hdf5
# 55s - loss: 0.9600 - acc: 0.5979 - val_loss: 1.0735 - val_acc: 0.5417
# Epoch 6/20
# Epoch 00005: val_loss improved from 1.07348 to 0.85877, saving model to weights.best.decor.cc_model.hdf5
# 58s - loss: 0.8352 - acc: 0.6186 - val_loss: 0.8588 - val_acc: 0.6875
# Epoch 7/20
# Epoch 00006: val_loss improved from 0.85877 to 0.83114, saving model to weights.best.decor.cc_model.hdf5
# 53s - loss: 0.6711 - acc: 0.7139 - val_loss: 0.8311 - val_acc: 0.6042
# Epoch 8/20
# Epoch 00007: val_loss improved from 0.83114 to 0.82473, saving model to weights.best.decor.cc_model.hdf5
# 58s - loss: 0.5744 - acc: 0.7758 - val_loss: 0.8247 - val_acc: 0.5208
# Epoch 9/20
# Epoch 00008: val_loss improved from 0.82473 to 0.72931, saving model to weights.best.decor.cc_model.hdf5
# 54s - loss: 0.5164 - acc: 0.8015 - val_loss: 0.7293 - val_acc: 0.7292
# Epoch 10/20
# Epoch 00009: val_loss improved from 0.72931 to 0.63694, saving model to weights.best.decor.cc_model.hdf5
# 54s - loss: 0.5024 - acc: 0.7964 - val_loss: 0.6369 - val_acc: 0.6875
# Epoch 11/20
# Epoch 00010: val_loss did not improve
# 51s - loss: 0.4586 - acc: 0.8144 - val_loss: 1.2850 - val_acc: 0.4792
# Epoch 12/20
# Epoch 00011: val_loss improved from 0.63694 to 0.53710, saving model to weights.best.decor.cc_model.hdf5
# 52s - loss: 0.4709 - acc: 0.8325 - val_loss: 0.5371 - val_acc: 0.8750
# Epoch 13/20
# Epoch 00012: val_loss did not improve
# 60s - loss: 0.3773 - acc: 0.8660 - val_loss: 0.5419 - val_acc: 0.8125
# Epoch 14/20
# Epoch 00013: val_loss did not improve
# 63s - loss: 0.3950 - acc: 0.8351 - val_loss: 0.9146 - val_acc: 0.5833
# Epoch 15/20
# Epoch 00014: val_loss did not improve
# 69s - loss: 0.4192 - acc: 0.8376 - val_loss: 0.5565 - val_acc: 0.7708
# Epoch 16/20
# Epoch 00015: val_loss improved from 0.53710 to 0.51523, saving model to weights.best.decor.cc_model.hdf5
# 62s - loss: 0.3778 - acc: 0.8814 - val_loss: 0.5152 - val_acc: 0.7500
# Epoch 17/20
# Epoch 00016: val_loss improved from 0.51523 to 0.43159, saving model to weights.best.decor.cc_model.hdf5
# 66s - loss: 0.3574 - acc: 0.8608 - val_loss: 0.4316 - val_acc: 0.8333
# Epoch 18/20
# Epoch 00017: val_loss did not improve
# 68s - loss: 0.2954 - acc: 0.8892 - val_loss: 0.8874 - val_acc: 0.6875
# Epoch 19/20
# Epoch 00018: val_loss improved from 0.43159 to 0.39349, saving model to weights.best.decor.cc_model.hdf5
# 61s - loss: 0.3061 - acc: 0.8840 - val_loss: 0.3935 - val_acc: 0.8542
# Epoch 20/20
# Epoch 00019: val_loss improved from 0.39349 to 0.35621, saving model to weights.best.decor.cc_model.hdf5
# 58s - loss: 0.2179 - acc: 0.9304 - val_loss: 0.3562 - val_acc: 0.8958

# %%
hide_code
# Plot the training history
history_plot(cc_history, 0)

# %%
hide_code
# Load the model with the best validation accuracy
cc_model.load_weights('weights.best.decor.cc_model.hdf5')
# Calculate classification accuracy on the testing set
cc_score = cc_model.evaluate(x_test, y_test)
cc_score
# Out:
# 49/49 [==============================] - 3s
# [0.49752859923304343, 0.83673469995965766]

# %%
hide_code
def cd_model(leaky_alpha):
    model = Sequential()
    # TODO: Define a model architecture
    model.add(Conv2D(32, (5, 5), padding='same', input_shape=x_train.shape[1:]))
    model.add(LeakyReLU(alpha=leaky_alpha))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(96, (5, 5)))
    model.add(LeakyReLU(alpha=leaky_alpha))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(GlobalMaxPooling2D()) 
    
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=leaky_alpha))
    model.add(Dropout(0.25)) 
    
    model.add(Dense(7))
    model.add(Activation('softmax'))
    
    # TODO: Compile the model
    model.compile(loss='categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])
    
    return model

# %%
hide_code
# Train the model
cd_model = cd_model(0.015)
cd_checkpointer = ModelCheckpoint(filepath='weights.best.decor.cd_model.hdf5', 
                                  verbose=2, save_best_only=True)
cd_history = cd_model.fit(x_train3, y_train3, 
                          epochs=20, batch_size=16, verbose=2,
                          validation_data=(x_valid3, y_valid3),
                          callbacks=[cd_checkpointer])
# Out:
# Train on 388 samples, validate on 48 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 1.57621, saving model to weights.best.decor.cd_model.hdf5
# 65s - loss: 1.7633 - acc: 0.2964 - val_loss: 1.5762 - val_acc: 0.3542
# Epoch 2/20
# Epoch 00001: val_loss improved from 1.57621 to 1.20153, saving model to weights.best.decor.cd_model.hdf5
# 83s - loss: 1.2408 - acc: 0.5155 - val_loss: 1.2015 - val_acc: 0.5417
# Epoch 3/20
# Epoch 00002: val_loss improved from 1.20153 to 1.02882, saving model to weights.best.decor.cd_model.hdf5
# 62s - loss: 1.0440 - acc: 0.6031 - val_loss: 1.0288 - val_acc: 0.6458
# Epoch 4/20
# Epoch 00003: val_loss did not improve
# 69s - loss: 0.8358 - acc: 0.6675 - val_loss: 1.5006 - val_acc: 0.4167
# Epoch 5/20
# Epoch 00004: val_loss improved from 1.02882 to 0.90145, saving model to weights.best.decor.cd_model.hdf5
# 56s - loss: 0.8291 - acc: 0.6598 - val_loss: 0.9014 - val_acc: 0.7083
# Epoch 6/20
# Epoch 00005: val_loss did not improve
# 55s - loss: 0.6709 - acc: 0.7371 - val_loss: 1.2930 - val_acc: 0.4375
# Epoch 7/20
# Epoch 00006: val_loss improved from 0.90145 to 0.77752, saving model to weights.best.decor.cd_model.hdf5
# 55s - loss: 0.7466 - acc: 0.7062 - val_loss: 0.7775 - val_acc: 0.7292
# Epoch 8/20
# Epoch 00007: val_loss did not improve
# 55s - loss: 0.6422 - acc: 0.7500 - val_loss: 1.3884 - val_acc: 0.5000
# Epoch 9/20
# Epoch 00008: val_loss improved from 0.77752 to 0.68584, saving model to weights.best.decor.cd_model.hdf5
# 54s - loss: 0.5635 - acc: 0.7990 - val_loss: 0.6858 - val_acc: 0.8125
# Epoch 10/20
# Epoch 00009: val_loss did not improve
# 55s - loss: 0.7984 - acc: 0.7423 - val_loss: 0.8730 - val_acc: 0.6458
# Epoch 11/20
# Epoch 00010: val_loss did not improve
# 55s - loss: 0.5221 - acc: 0.7938 - val_loss: 0.7816 - val_acc: 0.7292
# Epoch 12/20
# Epoch 00011: val_loss did not improve
# 56s - loss: 0.5066 - acc: 0.8067 - val_loss: 1.1301 - val_acc: 0.5625
# Epoch 13/20
# Epoch 00012: val_loss did not improve
# 55s - loss: 0.6138 - acc: 0.8144 - val_loss: 0.7792 - val_acc: 0.6667
# Epoch 14/20
# Epoch 00013: val_loss improved from 0.68584 to 0.66897, saving model to weights.best.decor.cd_model.hdf5
# 55s - loss: 0.3920 - acc: 0.8557 - val_loss: 0.6690 - val_acc: 0.7708
# Epoch 15/20
# Epoch 00014: val_loss did not improve
# 54s - loss: 0.3518 - acc: 0.8634 - val_loss: 0.6811 - val_acc: 0.7083
# Epoch 16/20
# Epoch 00015: val_loss improved from 0.66897 to 0.62791, saving model to weights.best.decor.cd_model.hdf5
# 55s - loss: 0.3919 - acc: 0.8505 - val_loss: 0.6279 - val_acc: 0.7917
# Epoch 17/20
# Epoch 00016: val_loss did not improve
# 55s - loss: 0.3204 - acc: 0.8763 - val_loss: 0.6984 - val_acc: 0.7500
# Epoch 18/20
# Epoch 00017: val_loss did not improve
# 56s - loss: 0.3396 - acc: 0.8763 - val_loss: 0.7717 - val_acc: 0.7708
# Epoch 19/20
# Epoch 00018: val_loss did not improve
# 55s - loss: 0.3448 - acc: 0.8634 - val_loss: 0.6590 - val_acc: 0.8333
# Epoch 20/20
# Epoch 00019: val_loss improved from 0.62791 to 0.53675, saving model to weights.best.decor.cd_model.hdf5
# 55s - loss: 0.2467 - acc: 0.9227 - val_loss: 0.5367 - val_acc: 0.8333

# %%
hide_code
# Plot the training history
history_plot(cd_history, 0)

# %%
hide_code
# Load the model with the best validation accuracy
cd_model.load_weights('weights.best.decor.cd_model.hdf5')
# Calculate classification accuracy on the testing set
cd_score = cd_model.evaluate(x_test3, y_test3)
cd_score
# Out:
# 49/49 [==============================] - 2s
# [0.59441830917280547, 0.81632653669435151]

# %%
hide_code
# Save experiment results for test points/ 20 epochs
leaky_alphas = np.array([0.005, 0.01, 0.015, 0.02, 0.025])
cd_losses = np.array([0.65711019720349995, 0.66739930911939971, 0.59441830917280547, 
                      0.66775868863475563, 0.68195151066293525])
cd_accuracies = np.array([0.83673469874323636, 0.79591837342904537, 0.81632653669435151, 
                          0.79591837342904537, 0.81632653547793022])

# %%
hide_code
# Plot the results
plt.figure(figsize=(18, 6))
plt.plot(leaky_alphas, cd_losses, '-o', color='slategray', label = 'loss')
plt.plot(leaky_alphas, cd_accuracies, '-o', color='#4876ff', label = 'accuracy')
plt.xlabel('leaky alphas')
plt.ylabel('results')
plt.legend(loc=3)
plt.title('Decor Recognition. Test Results for Color Images: Loss Function and Accuracy');

# %% [markdown]
# #### Country & Decor Recognition for Grayscaled Images

# %%
hide_code
def gray_cc_model():
    model = Sequential()
    
    # TODO: Define a model architecture
    model.add(Conv2D(32, (5, 5), padding='same', input_shape=x_train4.shape[1:]))
    model.add(Activation('relu'))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (5, 5)))
    model.add(Activation('relu'))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(GlobalMaxPooling2D()) 
    
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.25))   

    model.add(Dense(4))
    model.add(Activation('softmax'))
    
    # TODO: Compile the model
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

# %%
hide_code
# Train the model
gray_cc_model = gray_cc_model()
gray_cc_checkpointer = ModelCheckpoint(filepath='weights.best.decor.gray_cc_model.hdf5', 
                                       verbose=2, save_best_only=True)
gray_cc_history = gray_cc_model.fit(x_train2, y_train2, 
                                    epochs=30, batch_size=16, verbose=2,
                                    validation_data=(x_valid2, y_valid2),
                                    callbacks=[gray_cc_checkpointer])
# Out:
# Train on 388 samples, validate on 48 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.24995, saving model to weights.best.decor.gray_cc_model.hdf5
# 64s - loss: 1.1521 - acc: 0.5644 - val_loss: 1.2500 - val_acc: 0.5417
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.24995 to 1.19912, saving model to weights.best.decor.gray_cc_model.hdf5
# 60s - loss: 1.1145 - acc: 0.5876 - val_loss: 1.1991 - val_acc: 0.5417
# Epoch 3/30
# Epoch 00002: val_loss improved from 1.19912 to 1.15992, saving model to weights.best.decor.gray_cc_model.hdf5
# 57s - loss: 1.1125 - acc: 0.5876 - val_loss: 1.1599 - val_acc: 0.5417
# Epoch 4/30
# Epoch 00003: val_loss did not improve
# 60s - loss: 1.0971 - acc: 0.5876 - val_loss: 1.3011 - val_acc: 0.5417
# Epoch 5/30
# Epoch 00004: val_loss did not improve
# 60s - loss: 1.0931 - acc: 0.5876 - val_loss: 1.1628 - val_acc: 0.5417
# Epoch 6/30
# Epoch 00005: val_loss did not improve
# 58s - loss: 1.0862 - acc: 0.5876 - val_loss: 1.1817 - val_acc: 0.5417
# Epoch 7/30
# Epoch 00006: val_loss did not improve
# 62s - loss: 1.0839 - acc: 0.5876 - val_loss: 1.3420 - val_acc: 0.5417
# Epoch 8/30
# Epoch 00007: val_loss improved from 1.15992 to 1.13312, saving model to weights.best.decor.gray_cc_model.hdf5
# 61s - loss: 1.0646 - acc: 0.5876 - val_loss: 1.1331 - val_acc: 0.5417
# Epoch 9/30
# Epoch 00008: val_loss improved from 1.13312 to 1.12455, saving model to weights.best.decor.gray_cc_model.hdf5
# 63s - loss: 1.0540 - acc: 0.5876 - val_loss: 1.1245 - val_acc: 0.5417
# Epoch 10/30
# Epoch 00009: val_loss did not improve
# 68s - loss: 1.0535 - acc: 0.5902 - val_loss: 1.4395 - val_acc: 0.0417
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 64s - loss: 1.0656 - acc: 0.5799 - val_loss: 1.2086 - val_acc: 0.5417
# Epoch 12/30
# Epoch 00011: val_loss did not improve
# 61s - loss: 1.0112 - acc: 0.6005 - val_loss: 1.2481 - val_acc: 0.5417
# Epoch 13/30
# Epoch 00012: val_loss improved from 1.12455 to 1.09658, saving model to weights.best.decor.gray_cc_model.hdf5
# 62s - loss: 0.9650 - acc: 0.6005 - val_loss: 1.0966 - val_acc: 0.5417
# Epoch 14/30
# Epoch 00013: val_loss did not improve
# 63s - loss: 0.9776 - acc: 0.6160 - val_loss: 1.2824 - val_acc: 0.3750
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 59s - loss: 0.9568 - acc: 0.6082 - val_loss: 1.1200 - val_acc: 0.5417
# Epoch 16/30
# Epoch 00015: val_loss improved from 1.09658 to 1.09284, saving model to weights.best.decor.gray_cc_model.hdf5
# 62s - loss: 0.9181 - acc: 0.6160 - val_loss: 1.0928 - val_acc: 0.5417
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 66s - loss: 0.8977 - acc: 0.6392 - val_loss: 1.2781 - val_acc: 0.4167
# Epoch 18/30
# Epoch 00017: val_loss improved from 1.09284 to 1.04926, saving model to weights.best.decor.gray_cc_model.hdf5
# 64s - loss: 0.8957 - acc: 0.6418 - val_loss: 1.0493 - val_acc: 0.5625
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 65s - loss: 0.8172 - acc: 0.6572 - val_loss: 1.2944 - val_acc: 0.3958
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 64s - loss: 0.8287 - acc: 0.6701 - val_loss: 1.4721 - val_acc: 0.2708
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 63s - loss: 0.8374 - acc: 0.6572 - val_loss: 1.3951 - val_acc: 0.3333
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 65s - loss: 0.8005 - acc: 0.6778 - val_loss: 1.1439 - val_acc: 0.5208
# Epoch 23/30
# Epoch 00022: val_loss improved from 1.04926 to 1.01806, saving model to weights.best.decor.gray_cc_model.hdf5
# 59s - loss: 0.7555 - acc: 0.7088 - val_loss: 1.0181 - val_acc: 0.5833
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 65s - loss: 0.7395 - acc: 0.6985 - val_loss: 1.1566 - val_acc: 0.4167
# Epoch 25/30
# Epoch 00024: val_loss improved from 1.01806 to 1.00138, saving model to weights.best.decor.gray_cc_model.hdf5
# 65s - loss: 0.7378 - acc: 0.7216 - val_loss: 1.0014 - val_acc: 0.5833
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 65s - loss: 0.7309 - acc: 0.7036 - val_loss: 1.0549 - val_acc: 0.5208
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 66s - loss: 0.7076 - acc: 0.7216 - val_loss: 1.3105 - val_acc: 0.4375
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 63s - loss: 0.7120 - acc: 0.7268 - val_loss: 1.1061 - val_acc: 0.5208
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 65s - loss: 0.6373 - acc: 0.7629 - val_loss: 1.1418 - val_acc: 0.6042
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 64s - loss: 0.7167 - acc: 0.7216 - val_loss: 1.0340 - val_acc: 0.6042

# %%
hide_code
# Plot the training history
history_plot(gray_cc_history, 0)

# %%
hide_code
# Load the model with the best validation accuracy
gray_cc_model.load_weights('weights.best.decor.gray_cc_model.hdf5')
# Calculate classification accuracy on the testing set
gray_cc_score = gray_cc_model.evaluate(x_test2, y_test2)
gray_cc_score
# Out:
# 49/49 [==============================] - 2s
# [1.1797569357618993, 0.53061224550616981]

# %%
hide_code
def gray_cd_model(leaky_alpha):
    model = Sequential()
    
    # TODO: Define a model architecture
    model.add(Conv2D(32, (5, 5), padding='same', input_shape=x_train4.shape[1:]))
    model.add(LeakyReLU(alpha=leaky_alpha))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (5, 5)))
    model.add(LeakyReLU(alpha=leaky_alpha))    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(GlobalMaxPooling2D()) 
    
    model.add(Dense(1024, activation='tanh'))
    model.add(Dropout(0.25))   

    model.add(Dense(7))
    model.add(Activation('softmax'))
    
    # TODO: Compile the model
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

# %%
hide_code
# Train the model
gray_cd_model = gray_cd_model(0.025)
gray_cd_checkpointer = ModelCheckpoint(filepath='weights.best.decor.gray_cd_model.hdf5', 
                                       verbose=2, save_best_only=True)
gray_cd_history = gray_cd_model.fit(x_train4, y_train4, 
                                    epochs=30, batch_size=16, verbose=2,
                                    validation_data=(x_valid4, y_valid4),
                                    callbacks=[gray_cd_checkpointer])
# Out:
# Train on 388 samples, validate on 48 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.93175, saving model to weights.best.decor.gray_cd_model.hdf5
# 78s - loss: 2.0251 - acc: 0.1830 - val_loss: 1.9318 - val_acc: 0.1875
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.93175 to 1.91152, saving model to weights.best.decor.gray_cd_model.hdf5
# 76s - loss: 1.8754 - acc: 0.2036 - val_loss: 1.9115 - val_acc: 0.1875
# Epoch 3/30
# Epoch 00002: val_loss did not improve
# 71s - loss: 1.8730 - acc: 0.2191 - val_loss: 1.9409 - val_acc: 0.1042
# Epoch 4/30
# Epoch 00003: val_loss did not improve
# 63s - loss: 1.8274 - acc: 0.2345 - val_loss: 1.9942 - val_acc: 0.1250
# Epoch 5/30
# Epoch 00004: val_loss improved from 1.91152 to 1.89901, saving model to weights.best.decor.gray_cd_model.hdf5
# 71s - loss: 1.7856 - acc: 0.2526 - val_loss: 1.8990 - val_acc: 0.2500
# Epoch 6/30
# Epoch 00005: val_loss improved from 1.89901 to 1.85877, saving model to weights.best.decor.gray_cd_model.hdf5
# 78s - loss: 1.7470 - acc: 0.2655 - val_loss: 1.8588 - val_acc: 0.2708
# Epoch 7/30
# Epoch 00006: val_loss improved from 1.85877 to 1.80707, saving model to weights.best.decor.gray_cd_model.hdf5
# 66s - loss: 1.7194 - acc: 0.3273 - val_loss: 1.8071 - val_acc: 0.3125
# Epoch 8/30
# Epoch 00007: val_loss did not improve
# 71s - loss: 1.6895 - acc: 0.3531 - val_loss: 1.9106 - val_acc: 0.1875
# Epoch 9/30
# Epoch 00008: val_loss did not improve
# 81s - loss: 1.6511 - acc: 0.3686 - val_loss: 1.8609 - val_acc: 0.2083
# Epoch 10/30
# Epoch 00009: val_loss did not improve
# 84s - loss: 1.5697 - acc: 0.3866 - val_loss: 1.9974 - val_acc: 0.1667
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 73s - loss: 1.5590 - acc: 0.4149 - val_loss: 2.2103 - val_acc: 0.1250
# Epoch 12/30
# Epoch 00011: val_loss did not improve
# 76s - loss: 1.4991 - acc: 0.4330 - val_loss: 1.8839 - val_acc: 0.2083
# Epoch 13/30
# Epoch 00012: val_loss improved from 1.80707 to 1.75375, saving model to weights.best.decor.gray_cd_model.hdf5
# 83s - loss: 1.4769 - acc: 0.4562 - val_loss: 1.7538 - val_acc: 0.2917
# Epoch 14/30
# Epoch 00013: val_loss did not improve
# 92s - loss: 1.4133 - acc: 0.4459 - val_loss: 1.8347 - val_acc: 0.2500
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 84s - loss: 1.3596 - acc: 0.4897 - val_loss: 1.8479 - val_acc: 0.3542
# Epoch 16/30
# Epoch 00015: val_loss did not improve
# 86s - loss: 1.2380 - acc: 0.5387 - val_loss: 2.0784 - val_acc: 0.2917
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 82s - loss: 1.2655 - acc: 0.5361 - val_loss: 1.7629 - val_acc: 0.2500
# Epoch 18/30
# Epoch 00017: val_loss did not improve
# 88s - loss: 1.1794 - acc: 0.5799 - val_loss: 2.1501 - val_acc: 0.1458
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 80s - loss: 1.1350 - acc: 0.5567 - val_loss: 1.8679 - val_acc: 0.3542
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 87s - loss: 1.1278 - acc: 0.5851 - val_loss: 1.8540 - val_acc: 0.2917
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 78s - loss: 1.0388 - acc: 0.6392 - val_loss: 1.9504 - val_acc: 0.1875
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 80s - loss: 0.9895 - acc: 0.6521 - val_loss: 1.9455 - val_acc: 0.2708
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 81s - loss: 0.9689 - acc: 0.6675 - val_loss: 1.8257 - val_acc: 0.2708
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 84s - loss: 0.9212 - acc: 0.6546 - val_loss: 2.0521 - val_acc: 0.2917
# Epoch 25/30
# Epoch 00024: val_loss improved from 1.75375 to 1.72054, saving model to weights.best.decor.gray_cd_model.hdf5
# 91s - loss: 0.8533 - acc: 0.6985 - val_loss: 1.7205 - val_acc: 0.3333
# Epoch 26/30
# Epoch 00025: val_loss improved from 1.72054 to 1.70351, saving model to weights.best.decor.gray_cd_model.hdf5
# 78s - loss: 0.8613 - acc: 0.7010 - val_loss: 1.7035 - val_acc: 0.3125
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 84s - loss: 0.8010 - acc: 0.7191 - val_loss: 1.9107 - val_acc: 0.3125
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 76s - loss: 0.7074 - acc: 0.7526 - val_loss: 2.0055 - val_acc: 0.3542
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 79s - loss: 0.7673 - acc: 0.7165 - val_loss: 1.9194 - val_acc: 0.3333
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 74s - loss: 0.6929 - acc: 0.7912 - val_loss: 1.9260 - val_acc: 0.2500

# %%
hide_code
# Plot the training history
history_plot(gray_cd_history, 0)

# %%
hide_code
# Load the model with the best validation accuracy
gray_cd_model.load_weights('weights.best.decor.gray_cd_model.hdf5')
# Calculate classification accuracy on the testing set
gray_cd_score = gray_cd_model.evaluate(x_test4, y_test4)
gray_cd_score
# Out:
# 49/49 [==============================] - 4s
# [1.8407663958413261, 0.30612245050011849]

# %%
hide_code
# Save experiment results for test points/ 30 epochs
gray_cd_losses = np.array([1.777957059899155, 1.7298113861862494, 1.6672236432834548, 
                           2.0078208689786949, 1.8407663958413261])
gray_cd_accuracies = np.array([0.26530612260103226, 0.30612244928369714, 0.28571428579031205, 
                               0.224489797438894, 0.30612245050011849])

# %%
hide_code
# Plot the results
plt.figure(figsize=(18, 6))
plt.plot(gray_cd_losses, leaky_alphas, '-o', color='slategray', label = 'loss')
plt.plot(gray_cd_accuracies, leaky_alphas, '-o', color='#4876ff', label = 'accuracy')
plt.xlabel('results')
plt.ylabel('leaky alphas')
plt.legend()
plt.title('Decor Recognition. Test Results for Grayscaled Images: Loss Function and Accuracy');

# %% [markdown]
# ## Step 5. Create Neural Networks for Multi-Label Classification

# %% [markdown]
# ## Step 6. Colorization
